# %% [markdown]
# <a href="https://colab.research.google.com/github/miguelreyes19xd/Ejercicios-2.0/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
link= 'https://github.com/mike1502/THC/blob/2e5e372a50d035bca2ed991afb1e5a75b5de07d5/Python/BasesDeDatos/CalidadDelAire.csv'
code ='?raw=true'
url = link+code
df = pd.read_csv(url, sep=',', index_col=1)
df.head()
print(df)
# Out:
#               Measurement date  \
# Station code
# 101           2017-01-01 00:00
# 101           2017-01-01 01:00
# 101           2017-01-01 02:00
# 101           2017-01-01 03:00
# 101           2017-01-01 04:00
# ...                        ...
# 125           2019-12-31 19:00
# 125           2019-12-31 20:00
# 125           2019-12-31 21:00
# 125           2019-12-31 22:00
# 125           2019-12-31 23:00
#
#                                                         Address   Latitude  \
# Station code
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# ...                                                         ...        ...
# ...

# %%
df.head(10)
df.tail(647511)
# Out:
#               Measurement date  \
# Station code
# 101           2017-01-01 00:00
# 101           2017-01-01 01:00
# 101           2017-01-01 02:00
# 101           2017-01-01 03:00
# 101           2017-01-01 04:00
# ...                        ...
# 125           2019-12-31 19:00
# 125           2019-12-31 20:00
# 125           2019-12-31 21:00
# 125           2019-12-31 22:00
# 125           2019-12-31 23:00
#
#                                                         Address   Latitude  \
# Station code
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# ...                                                         ...        ...
# ...

# %% [markdown]
# To display the descriptive statistics of the DataFrame (`df.describe()`) in LaTeX format, you can use the `.to_latex()` method. This will generate a string that can be copied directly into a LaTeX document.

# %%
latex_table = df.describe().to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
#  & Latitude & Longitude & SO2 & NO2 & O3 & CO & PM10 & PM2.5 \\
# \midrule
# count & 647511.000000 & 647511.000000 & 647511.000000 & 647511.000000 & 647511.000000 & 647511.000000 & 647511.000000 & 647511.000000 \\
# mean & 37.553484 & 126.989340 & -0.001795 & 0.022519 & 0.017979 & 0.509197 & 43.708051 & 25.411995 \\
# std & 0.053273 & 0.078790 & 0.078832 & 0.115153 & 0.099308 & 0.405319 & 71.137342 & 43.924595 \\
# min & 37.452357 & 126.835151 & -1.000000 & -1.000000 & -1.000000 & -1.000000 & -1.000000 & -1.000000 \\
# 25% & 37.517528 & 126.927102 & 0.003000 & 0.016000 & 0.008000 & 0.300000 & 22.000000 & 11.000000 \\
# 50% & 37.544962 & 127.004850 & 0.004000 & 0.025000 & 0.021000 & 0.500000 & 35.000000 & 19.000000 \\
# 75% & 37.584848 & 127.047470 & 0.005000 & 0.038000 & 0.034000 & 0.600000 & 53.000000 & 31.000000 \\
# max & 37.658774 & 127.136792 & 3.736000 & 38.445000 & 33.600000 & 71.700000 & 3586.000000 & 6256.000000 \\
# \bottomrule
# ...

# %% [markdown]
# The output above is the LaTeX code for the descriptive statistics table. You can copy and paste this code into your LaTeX document to display the table.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 647511 entries, 101 to 125
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Measurement date  647511 non-null  object
#  1   Address           647511 non-null  object
#  2   Latitude          647511 non-null  float64
#  3   Longitude         647511 non-null  float64
#  4   SO2               647511 non-null  float64
#  5   NO2               647511 non-null  float64
#  6   O3                647511 non-null  float64
#  7   CO                647511 non-null  float64
#  8   PM10              647511 non-null  float64
#  9   PM2.5             647511 non-null  float64
# dtypes: float64(8), object(2)
# memory usage: 54.3+ MB

# %%
df.describe()
# Out:
#             Latitude      Longitude            SO2            NO2  \
# count  647511.000000  647511.000000  647511.000000  647511.000000
# mean       37.553484     126.989340      -0.001795       0.022519
# std         0.053273       0.078790       0.078832       0.115153
# min        37.452357     126.835151      -1.000000      -1.000000
# 25%        37.517528     126.927102       0.003000       0.016000
# 50%        37.544962     127.004850       0.004000       0.025000
# 75%        37.584848     127.047470       0.005000       0.038000
# max        37.658774     127.136792       3.736000      38.445000
#
#                   O3             CO           PM10          PM2.5
# count  647511.000000  647511.000000  647511.000000  647511.000000
# mean        0.017979       0.509197      43.708051      25.411995
# std         0.099308       0.405319      71.137342      43.924595
# min        -1.000000      -1.000000      -1.000000      -1.000000
# ...

# %%
import pandas as pd
link= 'https://github.com/mike1502/THC/blob/2e5e372a50d035bca2ed991afb1e5a75b5de07d5/Python/BasesDeDatos/CalidadDelAire.csv'
code ='?raw=true'
url = link+code
df = pd.read_csv(url, sep=',', index_col=1)
df.isna().sum()
# Out:
# Measurement date    0
# Address             0
# Latitude            0
# Longitude           0
# SO2                 0
# NO2                 0
# O3                  0
# CO                  0
# PM10                0
# PM2.5               0
# dtype: int64

# %%
df.SO2.describe()
# Out:
# count    647511.000000
# mean         -0.001795
# std           0.078832
# min          -1.000000
# 25%           0.003000
# 50%           0.004000
# 75%           0.005000
# max           3.736000
# Name: SO2, dtype: float64

# %%
red = '#FF0000'

plt.figure(figsize=(12,6))
df_filtered = df[df['SO2'] > 0]
plt.plot(df_filtered['Measurement date'], df_filtered['SO2'], label='Concentración SO2', color=red)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.title('Cambios en la Concentración de SO2 (Datos Filtrados)')
plt.xlabel('Tiempo')
plt.xticks(rotation=45)
plt.ylabel('SO2 (ppm)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.NO2.describe()
# Out:
# count    647511.000000
# mean          0.022519
# std           0.115153
# min          -1.000000
# 25%           0.016000
# 50%           0.025000
# 75%           0.038000
# max          38.445000
# Name: NO2, dtype: float64

# %% [markdown]
# First, let's make sure our `df_filtered` DataFrame has the 'Measurement date' column correctly formatted as datetime objects. This is crucial for accurate time-series plotting.

# %%
blue = '#0000FF'

plt.figure(figsize=(12,6))
plt.plot(df_filtered['Measurement date'], df_filtered['NO2'], label='Concentración NO2', color=blue)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.title('Cambios en la Concentración de NO2 (Datos Filtrados)')
plt.xlabel('Tiempo')
plt.xticks(rotation=45)
plt.ylabel('NO2 (ppm)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd # Ensure pandas is imported

# Ensure 'Measurement date' is a datetime object in the filtered DataFrame
df_filtered.loc[:, 'Measurement date'] = pd.to_datetime(df_filtered['Measurement date'])

print("DataFrame prepared for plotting.")
# Out:
# DataFrame prepared for plotting.

# %%
df.O3.describe()
# Out:
# count    647511.000000
# mean          0.017979
# std           0.099308
# min          -1.000000
# 25%           0.008000
# 50%           0.021000
# 75%           0.034000
# max          33.600000
# Name: O3, dtype: float64

# %%
green = '#008000'

plt.figure(figsize=(12,6))
plt.plot(df_filtered['Measurement date'], df_filtered['O3'], label='Concentración O3', color=green)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.title('Cambios en la Concentración de O3 (Datos Filtrados)')
plt.xlabel('Tiempo')
plt.xticks(rotation=45)
plt.ylabel('O3 (ppm)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.CO.describe()
# Out:
# count    647511.000000
# mean          0.509197
# std           0.405319
# min          -1.000000
# 25%           0.300000
# 50%           0.500000
# 75%           0.600000
# max          71.700000
# Name: CO, dtype: float64

# %%
orange = '#FFA500'

plt.figure(figsize=(12,6))
plt.plot(df_filtered['Measurement date'], df_filtered['CO'], label='Concentración CO', color=orange)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.title('Cambios en la Concentración de CO (Datos Filtrados)')
plt.xlabel('Tiempo')
plt.xticks(rotation=45)
plt.ylabel('CO (ppm)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.PM10.describe()
# Out:
# count    647511.000000
# mean         43.708051
# std          71.137342
# min          -1.000000
# 25%          22.000000
# 50%          35.000000
# 75%          53.000000
# max        3586.000000
# Name: PM10, dtype: float64

# %%
purple = '#800080'

plt.figure(figsize=(12,6))
plt.plot(df_filtered['Measurement date'], df_filtered['PM10'], label='Concentración PM10', color=purple)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.title('Cambios en la Concentración de PM10 (Datos Filtrados)')
plt.xlabel('Tiempo')
plt.xticks(rotation=45)
plt.ylabel('PM10 (µg/m³)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['PM2.5'].describe()
# Out:
# count    647511.000000
# mean         25.411995
# std          43.924595
# min          -1.000000
# 25%          11.000000
# 50%          19.000000
# 75%          31.000000
# max        6256.000000
# Name: PM2.5, dtype: float64

# %%
brown = '#A52A2A'# PASO 9: Matriz de correlación


plt.figure(figsize=(12,6))
plt.plot(df_filtered['Measurement date'], df_filtered['PM2.5'], label='Concentración PM2.5', color=brown)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
plt.title('Cambios en la Concentración de PM2.5 (Datos Filtrados)')
plt.xlabel('Tiempo')
plt.xticks(rotation=45)
plt.ylabel('PM2.5 (µg/m³)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# PASO 9: Matriz de correlación
# PASO 9: Matriz de correlación
df[['SO2','NO2','O3','CO','PM10','PM2.5']].corr()
# Out:
#             SO2       NO2        O3        CO      PM10     PM2.5
# SO2    1.000000  0.712422  0.805551  0.304923  0.048573  0.047531
# NO2    0.712422  1.000000  0.785805  0.245746  0.055532  0.057844
# O3     0.805551  0.785805  1.000000  0.188998  0.038602  0.033868
# CO     0.304923  0.245746  0.188998  1.000000  0.151166  0.182867
# PM10   0.048573  0.055532  0.038602  0.151166  1.000000  0.228984
# PM2.5  0.047531  0.057844  0.033868  0.182867  0.228984  1.000000

# %%
latex_corr_table = corr.to_latex()
print(latex_corr_table)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#  & SO2 & NO2 & O3 & CO & PM10 & PM2.5 \\
# \midrule
# SO2 & 1.000000 & 0.712422 & 0.805551 & 0.304923 & 0.048573 & 0.047531 \\
# NO2 & 0.712422 & 1.000000 & 0.785805 & 0.245746 & 0.055532 & 0.057844 \\
# O3 & 0.805551 & 0.785805 & 1.000000 & 0.188998 & 0.038602 & 0.033868 \\
# CO & 0.304923 & 0.245746 & 0.188998 & 1.000000 & 0.151166 & 0.182867 \\
# PM10 & 0.048573 & 0.055532 & 0.038602 & 0.151166 & 1.000000 & 0.228984 \\
# PM2.5 & 0.047531 & 0.057844 & 0.033868 & 0.182867 & 0.228984 & 1.000000 \\
# \bottomrule
# \end{tabular}

# %%
# Gráfica de correlación (heatmap simple)
import numpy as np

corr = df[['SO2','NO2','O3','CO','PM10','PM2.5']].corr()

plt.imshow(corr, cmap='viridis')
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Matriz de correlación")
plt.show()
